# %%
import numpy as np

# %%
# Rutas de los archivos
imagenes_train_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\train\imagenes_originales_train.npy"
imagenes_val_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\val\imagenes_originales_val.npy"
imagenes_test_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\test\imagenes_originales_test.npy"
heatmaps_train_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\train\heatmaps_train.npy"
heatmaps_val_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\val\heatmaps_val.npy"
heatmaps_test_path = r"D:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Datos\Arrays Heatmaps\test\heatmaps_test.npy"

# Cargar los archivos
imagenes_train = np.load(imagenes_train_path)
heatmaps_train = np.load(heatmaps_train_path)
imagenes_val = np.load(imagenes_val_path)
heatmaps_val = np.load(heatmaps_val_path)
imagenes_test = np.load(imagenes_test_path)
heatmaps_test = np.load(heatmaps_test_path)

# Convertir uint8 tensor a float32 y normalizar imágenes
imagenes_train = imagenes_train.astype('float32') / 255
imagenes_val = imagenes_val.astype('float32') /255
imagenes_test = imagenes_test.astype('float32') /255

# %%
# Verificar si hay valores NaN en las variables
nan_train_imagenes = np.isnan(imagenes_train).any()
nan_train_heatmaps = np.isnan(heatmaps_train).any()
nan_val_imagenes = np.isnan(imagenes_val).any()
nan_val_heatmaps = np.isnan(heatmaps_val).any()
nan_test_imagenes = np.isnan(imagenes_test).any()
nan_test_heatmaps = np.isnan(heatmaps_test).any()

# Imprimir los resultados
print("¿Hay valores NaN en imágenes de entrenamiento?", nan_train_imagenes)
print("¿Hay valores NaN en mapas de calor de entrenamiento?", nan_train_heatmaps)
print("¿Hay valores NaN en imágenes de validación?", nan_val_imagenes)
print("¿Hay valores NaN en mapas de calor de validación?", nan_val_heatmaps)
print("¿Hay valores NaN en imágenes de prueba?", nan_test_imagenes)
print("¿Hay valores NaN en mapas de calor de prueba?", nan_test_heatmaps)
# Out:
# ¿Hay valores NaN en imágenes de entrenamiento? False
# ¿Hay valores NaN en mapas de calor de entrenamiento? True
# ¿Hay valores NaN en imágenes de validación? False
# ¿Hay valores NaN en mapas de calor de validación? True
# ¿Hay valores NaN en imágenes de prueba? False
# ¿Hay valores NaN en mapas de calor de prueba? True

# %%
# Función para contar NaN en una variable
def count_nan(array):
    return np.sum(np.isnan(array))

# Contar NaN en cada variable
nan_count_train_imagenes = count_nan(imagenes_train)
nan_count_train_heatmaps = count_nan(heatmaps_train)
nan_count_val_imagenes = count_nan(imagenes_val)
nan_count_val_heatmaps = count_nan(heatmaps_val)
nan_count_test_imagenes = count_nan(imagenes_test)
nan_count_test_heatmaps = count_nan(heatmaps_test)

# Imprimir los resultados
print("Cantidad de valores NaN en imágenes de entrenamiento:", nan_count_train_imagenes)
print("Cantidad de valores NaN en mapas de calor de entrenamiento:", nan_count_train_heatmaps)
print("Cantidad de valores NaN en imágenes de validación:", nan_count_val_imagenes)
print("Cantidad de valores NaN en mapas de calor de validación:", nan_count_val_heatmaps)
print("Cantidad de valores NaN en imágenes de prueba:", nan_count_test_imagenes)
print("Cantidad de valores NaN en mapas de calor de prueba:", nan_count_test_heatmaps)
# Out:
# Cantidad de valores NaN en imágenes de entrenamiento: 0
# Cantidad de valores NaN en mapas de calor de entrenamiento: 150528
# Cantidad de valores NaN en imágenes de validación: 0
# Cantidad de valores NaN en mapas de calor de validación: 50176
# Cantidad de valores NaN en imágenes de prueba: 0
# Cantidad de valores NaN en mapas de calor de prueba: 12544

# %%
# Función para reemplazar NaN con 0
def replace_nan_with_zero(array):
    return np.nan_to_num(array)

# Reemplazar NaN con 0 en las variables que tienen NaN
heatmaps_train = replace_nan_with_zero(heatmaps_train)
heatmaps_val = replace_nan_with_zero(heatmaps_val)
heatmaps_test = replace_nan_with_zero(heatmaps_test)

# Verificar nuevamente si hay valores NaN
nan_train_heatmaps = np.isnan(heatmaps_train).any()
nan_val_heatmaps = np.isnan(heatmaps_val).any()
nan_test_heatmaps = np.isnan(heatmaps_test).any()

# Imprimir los resultados después de la transformación
print("¿Hay valores NaN en mapas de calor de entrenamiento?", nan_train_heatmaps)
print("¿Hay valores NaN en mapas de calor de validación?", nan_val_heatmaps)
print("¿Hay valores NaN en mapas de calor de prueba?", nan_test_heatmaps)
# Out:
# ¿Hay valores NaN en mapas de calor de entrenamiento? False
# ¿Hay valores NaN en mapas de calor de validación? False
# ¿Hay valores NaN en mapas de calor de prueba? False

# %%
# Obtener el tamaño de cada array
size_imagenes_train = imagenes_train.shape
size_heatmaps_train = heatmaps_train.shape
size_imagenes_val = imagenes_val.shape
size_heatmaps_val = heatmaps_val.shape
size_imagenes_test = imagenes_test.shape
size_heatmaps_test = heatmaps_test.shape

# Imprimir los tamaños
print("Tamaño de imagenes_train:", size_imagenes_train)
print("Tamaño de heatmaps_train:", size_heatmaps_train)
print("Tamaño de imagenes_val:", size_imagenes_val)
print("Tamaño de heatmaps_val:", size_heatmaps_val)
print("Tamaño de imagenes_test:", size_imagenes_test)
print("Tamaño de heatmaps_test:", size_heatmaps_test)
# Out:
# Tamaño de imagenes_train: (14918, 112, 112, 3)
# Tamaño de heatmaps_train: (14918, 112, 112, 7)
# Tamaño de imagenes_val: (2576, 112, 112, 3)
# Tamaño de heatmaps_val: (2576, 112, 112, 7)
# Tamaño de imagenes_test: (2552, 112, 112, 3)
# Tamaño de heatmaps_test: (2552, 112, 112, 7)

# %%
# Función para contar NaN en una variable
def count_nan(array):
    return np.sum(np.isnan(array))

# Contar NaN en cada variable
nan_count_train_imagenes = count_nan(imagenes_train)
nan_count_train_heatmaps = count_nan(heatmaps_train)
nan_count_val_imagenes = count_nan(imagenes_val)
nan_count_val_heatmaps = count_nan(heatmaps_val)
nan_count_test_imagenes = count_nan(imagenes_test)
nan_count_test_heatmaps = count_nan(heatmaps_test)

# Imprimir los resultados
print("Cantidad de valores NaN en imágenes de entrenamiento:", nan_count_train_imagenes)
print("Cantidad de valores NaN en mapas de calor de entrenamiento:", nan_count_train_heatmaps)
print("Cantidad de valores NaN en imágenes de validación:", nan_count_val_imagenes)
print("Cantidad de valores NaN en mapas de calor de validación:", nan_count_val_heatmaps)
print("Cantidad de valores NaN en imágenes de prueba:", nan_count_test_imagenes)
print("Cantidad de valores NaN en mapas de calor de prueba:", nan_count_test_heatmaps)
# Out:
# Cantidad de valores NaN en imágenes de entrenamiento: 0
# Cantidad de valores NaN en mapas de calor de entrenamiento: 0
# Cantidad de valores NaN en imágenes de validación: 0
# Cantidad de valores NaN en mapas de calor de validación: 0
# Cantidad de valores NaN en imágenes de prueba: 0
# Cantidad de valores NaN en mapas de calor de prueba: 0

# %%
# Ejemplo con una de tus matrices, ajusta según sea necesario
mapa_calor_ejemplo = heatmaps_train[0]  # Tomamos el primer mapa de calor para el ejemplo

# Obtener la forma del mapa de calor
forma_mapa_calor = mapa_calor_ejemplo.shape

# La última dimensión de la forma es la cantidad de canales (o clases)
num_classes = forma_mapa_calor[-1]

print("Número de clases:", num_classes)
# Out:
# Número de clases: 7

# %%
import matplotlib.pyplot as plt

# Seleccionamos la primera imagen de los conjuntos de entrenamiento
imagen = imagenes_test[11]
heatmap = heatmaps_test[11]

# Visualizamos la imagen de entrenamiento
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(imagen)
plt.title('Imagen de entrenamiento')
plt.axis('off')

# Para el heatmap, sumamos los canales para obtener una imagen en escala de grises
heatmap_gris = np.sum(heatmap, axis=-1)

# Normalizamos la imagen para que sus valores estén entre 0 y 1
heatmap_gris = (heatmap_gris - np.min(heatmap_gris)) / (np.max(heatmap_gris) - np.min(heatmap_gris))

plt.subplot(1, 2, 2)
plt.imshow(heatmap_gris, cmap='gray')
plt.title('Heatmap de entrenamiento')
plt.axis('off')

plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, Reshape
from tensorflow.keras.regularizers import l2
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.utils import Sequence
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# Define la clase del generador de datos
class DataGenerator(Sequence):
    def __init__(self, imagenes, heatmaps, batch_size=16):
        self.imagenes = imagenes
        self.heatmaps = heatmaps
        self.batch_size = batch_size
        self.indexes = np.arange(len(self.imagenes))

    def __len__(self):
        return int(np.ceil(len(self.imagenes) / self.batch_size))

    def __getitem__(self, index):
        start = index * self.batch_size
        end = (index + 1) * self.batch_size
        batch_x = self.imagenes[start:end]
        batch_y = self.heatmaps[start:end]
        return batch_x, batch_y

# %%
import tensorflow as tf
from tensorflow.keras.losses import Loss

class CustomLoss(Loss):
    def __init__(self, name='custom_loss'):
        super(CustomLoss, self).__init__(name=name)

    def call(self, y_true, y_pred):
        # y_true y y_pred son tensores de forma (batch_size, 112, 112, 7)
        
        # Calcula la pérdida canal por canal
        channel_losses = []
        for i in range(7):
            # Extrae el canal i de y_true e y_pred
            true_channel = y_true[:, :, :, i]
            pred_channel = y_pred[:, :, :, i]

            # Castear a tf.float32 antes de calcular la pérdida
            true_channel = tf.cast(true_channel, dtype=tf.float32)
            pred_channel = tf.cast(pred_channel, dtype=tf.float32)

            # Calcula la pérdida para el canal i (puedes personalizar la pérdida aquí)
            channel_loss = tf.keras.losses.MeanSquaredError()(true_channel, pred_channel)
            
            # Agrega la pérdida del canal i a la lista
            channel_losses.append(channel_loss)
        
        # Devuelve la pérdida total como la media de las pérdidas de cada canal
        return tf.reduce_mean(channel_losses, axis=0)

# %%
# Crear un modelo secuencial
model = Sequential()

# Base convolucional
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001), input_shape=(112, 112, 3)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(512, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(1024, (3, 3), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.5))

# Regularización L2
model.add(Flatten())
model.add(Dense(112, activation='relu', kernel_regularizer=l2(0.0001)))
model.add(BatchNormalization())
model.add(Dense(112 * 112 * 7, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Reshape((112, 112, 7)))
model.add(Dense(7, activation='sigmoid'))


# Compilar el modelo
model.compile(optimizer='adam', loss=CustomLoss(), metrics=['accuracy'])

# Crear instancias del generador de datos para entrenamiento y validación
train_generator = DataGenerator(imagenes_train, heatmaps_train, batch_size=16)
val_generator = DataGenerator(imagenes_val, heatmaps_val, batch_size=16)
test_generator = DataGenerator(imagenes_test, heatmaps_test, batch_size=16)

# Entrenar el modelo
history = model.fit(train_generator, epochs=10, validation_data=val_generator)

# Evaluar el modelo en datos de prueba utilizando el generador
test_loss, test_dice_score = model.evaluate(test_generator)
print(f'Loss en datos de prueba: {test_loss}')
print(f'DICE SCORE en datos de prueba: {test_dice_score}')
# Out:
# Epoch 1/10
# 933/933 [==============================] - 40s 41ms/step - loss: 25.8665 - accuracy: 0.1248 - val_loss: 25.7749 - val_accuracy: 0.0156
# Epoch 2/10
# 933/933 [==============================] - 38s 41ms/step - loss: 25.8060 - accuracy: 0.0862 - val_loss: 25.7411 - val_accuracy: 0.0178
# Epoch 3/10
# 933/933 [==============================] - 38s 41ms/step - loss: 25.7864 - accuracy: 0.0989 - val_loss: 25.7191 - val_accuracy: 0.0241
# Epoch 4/10
# 933/933 [==============================] - 38s 40ms/step - loss: 25.7732 - accuracy: 0.1008 - val_loss: 25.7059 - val_accuracy: 0.0245
# Epoch 5/10
# 933/933 [==============================] - 38s 40ms/step - loss: 25.7636 - accuracy: 0.1155 - val_loss: 25.6947 - val_accuracy: 0.0274
# Epoch 6/10
# 933/933 [==============================] - 38s 40ms/step - loss: 25.7559 - accuracy: 0.1319 - val_loss: 25.6849 - val_accuracy: 0.0271
# Epoch 7/10
# 933/933 [==============================] - 38s 41ms/step - loss: 25.7502 - accuracy: 0.1413 - val_loss: 25.6808 - val_accuracy: 0.0284
# Epoch 8/10
# 933/933 [==============================] - 38s 41ms/step - loss: 25.7458 - accuracy: 0.1484 - val_loss: 25.6740 - val_accuracy: 0.0317
# Epoch 9/10
# 933/933 [==============================] - 38s 41ms/step - loss: 25.7424 - accuracy: 0.1533 - val_loss: 25.6727 - val_accuracy: 0.0417
# Epoch 10/10
# 933/933 [==============================] - 38s 40ms/step - loss: 25.7395 - accuracy: 0.1617 - val_loss: 25.6666 - val_accuracy: 0.0405
# 160/160 [==============================] - 2s 11ms/step - loss: 25.6588 - accuracy: 0.0404
# Loss en datos de prueba: 25.658788681030273
# DICE SCORE en datos de prueba: 0.040410418063402176

# %%
# Supongamos que 'imagenes_test' es tu conjunto de datos de prueba
imagen_test = imagenes_test[400]  # Tomamos la primera imagen de prueba

import matplotlib.pyplot as plt

# Generar la predicción para la imagen de prueba
prediccion = model.predict(np.expand_dims(imagen_test, axis=0))

# La predicción tendrá la forma (1, 112, 112, 7), por lo que eliminamos la primera dimensión
prediccion = np.squeeze(prediccion)

# Sumamos los canales para obtener una imagen en escala de grises
imagen_salida = np.sum(prediccion, axis=-1)

# Normalizamos la imagen para que sus valores estén entre 0 y 1
imagen_salida = (imagen_salida - np.min(imagen_salida)) / (np.max(imagen_salida) - np.min(imagen_salida))

# Mostramos la imagen
plt.imshow(imagen_salida, cmap='gray')
plt.show()
# Out:
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x0000020F7DA8CC10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 399ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np

# Obtener algunas imágenes de prueba y las salidas esperadas
test_images, test_heatmaps = test_generator[0]  # Aquí asumimos que el primer lote se utiliza para la visualización
num_samples = test_images.shape[0]

# Obtener predicciones del modelo
predictions = model.predict(test_images)

# Elegir aleatoriamente una muestra para la visualización
sample_index = np.random.choice(num_samples, size=2, replace=False)[0]

# Visualizar las imágenes, salidas esperadas y predicciones para cada canal
for channel in range(test_heatmaps.shape[-1]):
    plt.figure(figsize=(15, 5))

    # Imagen de entrada
    plt.subplot(1, 3, 1)
    plt.imshow(test_images[sample_index])
    plt.title('Imagen de entrada')

    # Salida esperada (ground truth) para el canal actual
    plt.subplot(1, 3, 2)
    plt.imshow(test_heatmaps[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Salida esperada - Canal {channel}')

    # Predicción del modelo para el canal actual
    plt.subplot(1, 3, 3)
    plt.imshow(predictions[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Predicción del modelo - Canal {channel}')

    plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
from tensorflow.keras.applications import VGG16,ResNet50V2
from tensorflow.keras.models import Model

# Cargar el modelo ResNEt50V2 preentrenado
base_model = ResNet50V2(weights='imagenet', include_top=False, input_shape=(112, 112, 3))

# Congelar las capas del modelo base
for layer in base_model.layers:
    layer.trainable = False

# Agregar capas personalizadas al modelo
x = base_model.output
x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = Conv2D(512, (3, 3), padding='same', activation='relu')(x)
x = MaxPooling2D((2, 2))(x)

x = Dropout(0.5)(x)

# Regularización L2
x = Flatten()(x)
x = Dense(2048, activation='relu', kernel_regularizer=l2(0.0001))(x)
x = Dropout(0.5)(x)
x = Dense(1024, activation='relu', kernel_regularizer=l2(0.0001))(x)
x = Dropout(0.5)(x)
x = Dense(112 * 112 * 7, activation='sigmoid')(x)
x = Dropout(0.5)(x)
output_layer = Reshape((112, 112, 7))(x)

# Crear el modelo completo
model = Model(inputs=base_model.input, outputs=output_layer)


# Compilar el modelo
model.compile(optimizer='adam', loss=CustomLoss(), metrics=['accuracy'])

# Crear instancias del generador de datos para entrenamiento y validación
train_generator = DataGenerator(imagenes_train, heatmaps_train, batch_size=16)
val_generator = DataGenerator(imagenes_val, heatmaps_val, batch_size=16)
test_generator = DataGenerator(imagenes_test, heatmaps_test, batch_size=16)

# Entrenar el modelo
history = model.fit(train_generator, epochs=10, validation_data=val_generator)

# Evaluar el modelo en datos de prueba utilizando el generador
test_loss, test_dice_score = model.evaluate(test_generator)
print(f'Loss en datos de prueba: {test_loss}')
print(f'DICE SCORE en datos de prueba: {test_dice_score}')
# Out:
# Epoch 1/20
# 933/933 [==============================] - 41s 42ms/step - loss: 25.9264 - accuracy: 0.9865 - val_loss: 25.8966 - val_accuracy: 0.9889
# Epoch 2/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9125 - accuracy: 0.9857 - val_loss: 25.8975 - val_accuracy: 0.9895
# Epoch 3/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9125 - accuracy: 0.9800 - val_loss: 25.8958 - val_accuracy: 0.9879
# Epoch 4/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9123 - accuracy: 0.9895 - val_loss: 25.8960 - val_accuracy: 0.9880
# Epoch 5/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9120 - accuracy: 0.9896 - val_loss: 25.8961 - val_accuracy: 0.9884
# Epoch 6/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9123 - accuracy: 0.9894 - val_loss: 25.8973 - val_accuracy: 0.9892
# Epoch 7/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9133 - accuracy: 0.9899 - val_loss: 25.8977 - val_accuracy: 0.9892
# Epoch 8/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9137 - accuracy: 0.9902 - val_loss: 25.8983 - val_accuracy: 0.9896
# Epoch 9/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9139 - accuracy: 0.9902 - val_loss: 25.8983 - val_accuracy: 0.9897
# Epoch 10/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9139 - accuracy: 0.9901 - val_loss: 25.8981 - val_accuracy: 0.9897
# Epoch 11/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9139 - accuracy: 0.9902 - val_loss: 25.8983 - val_accuracy: 0.9898
# Epoch 12/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9138 - accuracy: 0.9904 - val_loss: 25.8980 - val_accuracy: 0.9899
# Epoch 13/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9138 - accuracy: 0.9902 - val_loss: 25.8978 - val_accuracy: 0.9895
# Epoch 14/20
# 933/933 [==============================] - 39s 42ms/step - loss: 25.9136 - accuracy: 0.9902 - val_loss: 25.8979 - val_accuracy: 0.9898
# Epoch 15/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9138 - accuracy: 0.9828 - val_loss: 25.8980 - val_accuracy: 0.9899
# Epoch 16/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9141 - accuracy: 0.9708 - val_loss: 25.8989 - val_accuracy: 0.9898
# Epoch 17/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9142 - accuracy: 0.9904 - val_loss: 25.8984 - val_accuracy: 0.9899
# Epoch 18/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9139 - accuracy: 0.9905 - val_loss: 25.8983 - val_accuracy: 0.9899
# Epoch 19/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9140 - accuracy: 0.9902 - val_loss: 25.8987 - val_accuracy: 0.9899
# Epoch 20/20
# 933/933 [==============================] - 39s 41ms/step - loss: 25.9141 - accuracy: 0.9904 - val_loss: 25.8982 - val_accuracy: 0.9897
# 160/160 [==============================] - 3s 22ms/step - loss: 25.8907 - accuracy: 0.9896
# Loss en datos de prueba: 25.890745162963867
# DICE SCORE en datos de prueba: 0.9896326661109924

# %%
import matplotlib.pyplot as plt
import numpy as np

# Obtener algunas imágenes de prueba y las salidas esperadas
test_images, test_heatmaps = test_generator[0]  # Aquí asumimos que el primer lote se utiliza para la visualización
num_samples = test_images.shape[0]

# Obtener predicciones del modelo
predictions = model.predict(test_images)

# Elegir aleatoriamente una muestra para la visualización
sample_index = np.random.choice(num_samples, size=2, replace=False)[0]

# Visualizar las imágenes, salidas esperadas y predicciones para cada canal
for channel in range(test_heatmaps.shape[-1]):
    plt.figure(figsize=(15, 5))

    # Imagen de entrada
    plt.subplot(1, 3, 1)
    plt.imshow(test_images[sample_index])
    plt.title('Imagen de entrada')

    # Salida esperada (ground truth) para el canal actual
    plt.subplot(1, 3, 2)
    plt.imshow(test_heatmaps[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Salida esperada - Canal {channel}')

    # Predicción del modelo para el canal actual
    plt.subplot(1, 3, 3)
    plt.imshow(predictions[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Predicción del modelo - Canal {channel}')

    plt.show()
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, MaxPooling2D, Dropout, Flatten, Dense, Reshape, UpSampling2D, concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# Entrada
input_layer = Input(shape=(112, 112, 3))

# Base convolucional
conv1 = Conv2D(32, (3, 3), padding='same', activation='relu', kernel_regularizer=l2(0.0001))(input_layer)
conv1 = BatchNormalization()(conv1)
conv1 = Conv2D(32, (3, 3), padding='same', activation='relu')(conv1)
conv1 = BatchNormalization()(conv1)
pool1 = MaxPooling2D((2, 2))(conv1)

conv2 = Conv2D(64, (3, 3), padding='same', activation='relu')(pool1)
conv2 = BatchNormalization()(conv2)
conv2 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv2)
conv2 = BatchNormalization()(conv2)
pool2 = MaxPooling2D((2, 2))(conv2)

conv3 = Conv2D(128, (3, 3), padding='same', activation='relu')(pool2)
conv3 = BatchNormalization()(conv3)
conv3 = Conv2D(128, (3, 3), padding='same', activation='relu')(conv3)
conv3 = BatchNormalization()(conv3)
pool3 = MaxPooling2D((2, 2))(conv3)

conv4 = Conv2D(256, (3, 3), padding='same', activation='relu')(pool3)
conv4 = BatchNormalization()(conv4)
conv4 = Conv2D(256, (3, 3), padding='same', activation='relu')(conv4)
conv4 = BatchNormalization()(conv4)
pool4 = MaxPooling2D((2, 2))(conv4)
drop4 = Dropout(0.5)(pool4)

conv5 = Conv2D(512, (3, 3), padding='same', activation='relu')(drop4)
conv5 = BatchNormalization()(conv5)
conv5 = Conv2D(512, (3, 3), padding='same', activation='relu')(conv5)
conv5 = BatchNormalization()(conv5)
drop5 = Dropout(0.5)(conv5)

# Upsampling y conexiones de salto
up6 = UpSampling2D((2, 2))(drop5)
up6 = concatenate([up6, conv4], axis=3)
conv6 = Conv2D(256, (3, 3), padding='same', activation='relu')(up6)
conv6 = BatchNormalization()(conv6)
conv6 = Conv2D(256, (3, 3), padding='same', activation='relu')(conv6)
conv6 = BatchNormalization()(conv6)

up7 = UpSampling2D((2, 2))(conv6)
up7 = concatenate([up7, conv3], axis=3)
conv7 = Conv2D(128, (3, 3), padding='same', activation='relu')(up7)
conv7 = BatchNormalization()(conv7)
conv7 = Conv2D(128, (3, 3), padding='same', activation='relu')(conv7)
conv7 = BatchNormalization()(conv7)

up8 = UpSampling2D((2, 2))(conv7)
up8 = concatenate([up8, conv2], axis=3)
conv8 = Conv2D(64, (3, 3), padding='same', activation='relu')(up8)
conv8 = BatchNormalization()(conv8)
conv8 = Conv2D(64, (3, 3), padding='same', activation='relu')(conv8)
conv8 = BatchNormalization()(conv8)

up9 = UpSampling2D((2, 2))(conv8)
up9 = concatenate([up9, conv1], axis=3)
conv9 = Conv2D(32, (3, 3), padding='same', activation='relu')(up9)
conv9 = BatchNormalization()(conv9)
conv9 = Conv2D(32, (3, 3), padding='same', activation='relu')(conv9)
conv9 = BatchNormalization()(conv9)

# Capa de salida
conv10 = Conv2D(7, (1, 1), activation='sigmoid')(conv9)

# Modelo U-Net
model = Model(inputs=input_layer, outputs=conv10)

# Compilar el modelo
model.compile(optimizer=Adam(), loss=CustomLoss(), metrics=['accuracy'])

# Crear instancias del generador de datos para entrenamiento y validación
train_generator = DataGenerator(imagenes_train, heatmaps_train, batch_size=16)
val_generator = DataGenerator(imagenes_val, heatmaps_val, batch_size=16)
test_generator = DataGenerator(imagenes_test, heatmaps_test, batch_size=16)

# Entrenar el modelo
history = model.fit(train_generator, epochs=30, validation_data=val_generator)

# Evaluar el modelo en datos de prueba utilizando el generador
test_loss, test_dice_score = model.evaluate(test_generator)
print(f'Loss en datos de prueba: {test_loss}')
print(f'DICE SCORE en datos de prueba: {test_dice_score}')
# Out:
# Epoch 1/30
# 933/933 [==============================] - 66s 67ms/step - loss: 25.6815 - accuracy: 0.0417 - val_loss: 25.6383 - val_accuracy: 0.0439
# Epoch 2/30
# 933/933 [==============================] - 62s 66ms/step - loss: 25.6478 - accuracy: 0.0956 - val_loss: 25.6334 - val_accuracy: 0.3551
# Epoch 3/30
# 116/933 [==>...........................] - ETA: 52s - loss: 25.6595 - accuracy: 0.3830
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Tec\7mo Smestre\Inteligencia Artificial II\Reto\Codigo\Entrenamiento_heatmaps_6.0.ipynb Cell 18 line 8
#      <a href='vscode-notebook-cell:/d%3A/Tec/7mo%20Smestre/Inteligencia%20Artificial%20II/Reto/Codigo/Entrenamiento_heatmaps_6.0.ipynb#X22sZmlsZQ%3D%3D?line=81'>82</a> test_generator = DataGenerator(imagenes_test, heatmaps_test, batch_size=16)
#      <a href='vscode-notebook-cell:/d%3A/Tec/7mo%20Smestre/Inteligencia%20Artificial%20II/Reto/Codigo/Entrenamiento_heatmaps_6.0.ipynb#X22sZmlsZQ%3D%3D?line=83'>84</a> # Entrenar el modelo
# ---> <a href='vscode-notebook-cell:/d%3A/Tec/7mo%20Smestre/Inteligencia%20Artificial%20II/Reto/Codigo/Entrenamiento_heatmaps_6.0.ipynb#X22sZmlsZQ%3D%3D?line=84'>85</a> history = model.fit(train_generator, epochs=30, validation_data=val_generator)
#      <a href='vscode-notebook-cell:/d%3A/Tec/7mo%20Smestre/Inteligencia%20Artificial%20II/Reto/Codigo/Entrenamiento_heatmaps_6.0.ipynb#X22sZmlsZQ%3D%3D?line=86'>87</a> # Evaluar el modelo en datos de prueba utilizando el generador
#      <a href='vscode-notebook-cell:/d%3A/Tec/7mo%20Smestre/Inteligencia%20Artificial%20II/Reto/Codigo/Entrenamiento_heatmaps_6.0.ipynb#X22sZmlsZQ%3D%3D?line=87'>88</a> test_loss, test_dice_score = model.evaluate(test_generator)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:388, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
# --> 388     hook(batch, logs)
#     390 if self._check_timing:
#     391     if hook_name not in self._hook_times:
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:1081, in ProgbarLogger.on_train_batch_end(self, batch, logs)
#    1080 def on_train_batch_end(self, batch, logs=None):
# -> 1081     self._batch_update_progbar(batch, logs)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\callbacks.py:1157, in ProgbarLogger._batch_update_progbar(self, batch, logs)
#    1153     self.seen += add_seen
#    1155 if self.verbose == 1:
#    1156     # Only block async when verbose = 1.
# -> 1157     logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1158     self.progbar.update(self.seen, list(logs.items()), finalize=False)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File c:\Users\vhae1\anaconda3\envs\tf\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
import numpy as np

# Obtener algunas imágenes de prueba y las salidas esperadas
test_images, test_heatmaps = test_generator[0]  # Aquí asumimos que el primer lote se utiliza para la visualización
num_samples = test_images.shape[0]

# Obtener predicciones del modelo
predictions = model.predict(test_images)

# Elegir aleatoriamente una muestra para la visualización
sample_index = np.random.choice(num_samples, size=2, replace=False)[0]

# Visualizar las imágenes, salidas esperadas y predicciones para cada canal
for channel in range(test_heatmaps.shape[-1]):
    plt.figure(figsize=(15, 5))

    # Imagen de entrada
    plt.subplot(1, 3, 1)
    plt.imshow(test_images[sample_index])
    plt.title('Imagen de entrada')

    # Salida esperada (ground truth) para el canal actual
    plt.subplot(1, 3, 2)
    plt.imshow(test_heatmaps[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Salida esperada - Canal {channel}')

    # Predicción del modelo para el canal actual
    plt.subplot(1, 3, 3)
    plt.imshow(predictions[sample_index, :, :, channel], cmap='jet', alpha=0.5)
    plt.title(f'Predicción del modelo - Canal {channel}')

    plt.show()
# Out:
# 1/1 [==============================] - 0s 96ms/step
